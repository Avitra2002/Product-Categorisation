# %%
import vertexai
from vertexai.generative_models import GenerativeModel, GenerationConfig
import pandas as pd
from collections import defaultdict
import json
import re

# Initialize Vertex AI
project_id = "jbaaam"
vertexai.init(project=project_id, location="us-central1")
model = GenerativeModel(model_name="gemini-1.5-flash-001")
generation_config = GenerationConfig(
    temperature=0.3,
    top_p=0.9,
    top_k=2,
    candidate_count=1,
    max_output_tokens=900,
)


path = '/Users/joel/Desktop/SUTD /T5/SDS/actionablestest.xlsx'
df = pd.read_excel(path)

product_feedback = defaultdict(list)
for _, row in df.iterrows():
    product_feedback[row['Subcategory ']].append(row['Feedback '])

summarized_actions = []

for product, feedbacks in product_feedback.items():

    combined_feedback = " | ".join(feedbacks)
    
    prompt = f"""
    Product: {product}
    Combined Feedback: {combined_feedback}

    Based on the combined feedback for the product "{product}", please generate one general actionable item that addresses the main themes or issues across all the feedback for this product.

    Format the response as follows:
    Category: [To Fix/To Promote/Keep in mind/To Amplify]
    Action: [Summarized general action]

    Ensure that the category is classified according to this:
    1. To Fix: regarding issues that require maintenance or repair, where services are not working
    2. To Promote: regarding feedback that talks about certain promotions that could be done or undermarketed stuff.
    3. Keep in mind: regarding feedback that compliments the service, and any form of suggestions
    4. To Amplify: regarding feedback that is neutral, but could have room for improvements.
    
    Ensure that the action is:
    1. Always provided
    2. As general as possible while still being relevant to the specific product. It should be very general.
    3. Addresses the most common or significant issues/themes in the feedback
    4. Focused on improving the overall product or customer experience

    Examples of generalized actions for various products:
    1. Savings Account: "Enhance interest rates and account features to improve customer satisfaction"
    2. Mobile Banking App: "Prioritize app stability and user interface improvements based on customer feedback"
    3. Credit Cards: "Revamp reward program and address common billing concerns"
    4. Customer Service: "Implement comprehensive training program to address recurring customer issues"
    5. Loans: "Streamline application process and improve communication throughout the loan lifecycle"

    
    Ensure response is:
    1. Always includes all specified fields
    2. Is formatted clearly and consistently according to the provided format, DO NOT GIVE ANY HEADERS
    Remember to tailor the action to the specific product and the themes present in the combined feedback.
    REMEMBER TO COMPLETE ALL GENERATED RESPONSES FOR ALL PRODUCTS 
    """

    response = model.generate_content(prompt, generation_config=generation_config)
    response_text = response.text.strip()
    #print(f"Raw response for product '{product}':\n{response_text}\n")
    response_text_cleaned = re.sub(r'^##.*?\n', '', response_text, flags=re.DOTALL).strip()

 
    actionable_category = 'Not specified'
    action = 'Not specified'

    lines = response_text_cleaned.split('\n')
    current_item = {
        'subproduct': product,
        'actionable_category' : actionable_category,
        'action': action,
        'feedback_count': len(feedbacks),
        'feedback_data': feedbacks
    }
    for line in lines:
        line = line.strip()
        if line.startswith('Category:'):
            current_item['actionable_category'] = line.split(':')[1].strip()
        elif line.startswith('Action:'):
            current_item['action'] = line.split(':')[1].strip()

    if 'actionable_category' in current_item  and 'action' in current_item:
        summarized_actions.append(current_item)
    else:
        print(f"Warning: Incomplete response for product '{product}'. Response text: {response_text}")

output = json.dumps(summarized_actions, indent=4)
print(output)
# Out:
# [
#     {
#         "subproduct": "SSB",
#         "actionable_category": "To Fix",
#         "action": "Improve the reliability and functionality of SSB ATMs and CDMs, including addressing issues with keypad functionality, cash dispensing, coin deposit accuracy, and passbook printing.",
#         "feedback_count": 14,
#         "feedback_data": [
#             "Feedback in the morning sun shine on the ATM  machine is too bright and therefore not able to see anything on the screen feedback should put some sunshine blinds  ayer rajah market, infront of ntuc ATM screen not clear due to the sun (left machine)",
#             "No need all back , CM like to report that the SSB - ATM is faulty unable to press on the keypad on the ATM. ",
#             "CM feedback that our ssb cash deposit machine is too tedious and confusing. rejecting notes first time and accepting it the next time. cm said that this will create more error in handling money especially for our senior customers.",
#             "unable to dispense cash. Happen to multiple customer as well.  ",
#             "serangoon north ave 3 atm shows this terminal is temporarily offline",
#             "CM giving feedback that when updating passbook the printing is very faint and hard to cm to see.",
#             "CM having issue requesting for cash exchange.",
#             "CM feedback all 3 machines ID below show can small change $2 & $5 notes however when doing the rqst, it show unavailable ",
#             "Cm work at grassroots and he take his own money to help the community exchange their coins to cash. Hence he end up with many coins to deposit. He heard rumours that the DBS CDM always spoil and best to us POSB CDM instead. His experience with tanjong pagar AND tiong bahru has always been smooth, having the coins deposit complete in les than 60 seconds while the CDM at DBS says will take a while. ",
#             "Cm reported for SSB coin deposit dispute in 09/03/2024. Cm informed that when he called in, PCSO mentioned that he can leave the SSB machine and the coins will be retained in the machine.  In this call, cm mentioned that he wishes to dispute on the amount that he received as it cannot be just $32.75.  Cm mentioned that the partial coins that he collected was only abit and the coins left in the machine was more than $32.75.  Cm wishes to view the CCTV in person and I informed that if he wishes to do so, he may lodge a police report in order to view the CCTV. Cm do not wish to lodge and mentioned that I am using this against cm, in which I do not understand what he meant.  Cm\u2019s wife was shouting in the background that they are going to report to MAS as well as the press regarding this issue as they feel that that we are not following up closely in this matter. Cm wish to speak to a manager in this matter as he feel that we are not following up on this matter and no one is assisting him and he still wants to view the CCTV in person. ",
#             "Cannot withdraw cash no followup with cm required",
#             "I am sad that the atm machine was removed at the month of december 2023 at location 521866 level 1. This is a big incovenience to dwellers living around the vicinty. The building has a M1 level or level 2 which can house the atm instead of completely removing it from the building. Please look into whether can reinstall an atm in the building. Thank you.\"",
#             "CM would like to feedback why there is no receipt gen and no record in passbook after she withdraw at ATM",
#             "Date and time of Visits:  1) 14 Mar, 8am 2) 15 Mar, 5.45pm 3) 18 Mar, afternoon (can\u2019t remember exact time) 4) 18 Mar, 6pm. Machine ID:  Location (If No Machine ID): Blk 290 Yishun St 22.  Type Of Transaction:  No small notes available Method Of Transaction: ATM but didn\u2019t put in cause the machine always show the smaller notes are unavailable (like the previous photo I sent)"
#         ]
#     },
#     {
#         "subproduct": "VTM",
#         "actionable_category": "To Fix",
#         "action": "Improve the reliability and functionality of VTMs, including addressing technical issues and ensuring consistent access to customer service representatives.",
#         "feedback_count": 2,
#         "feedback_data": [
#             "I was trying to help my domestic helper activate her multi-currency DBS visa debit card. I was at the VTM at ARC (Labrador) at 5.55pm. Was told by the officer on video chat to exit and try again. I did that but I couldn't reconnect to the officer. Was told that no officer was available. It appeared to be a feeble attempt by your officer to dismiss serving me at the end of the day, knowing that there was no recourse for me to reconnect to him. You could review the CCTV recordings and advise why that unprofessional service given. I now have to find time to go back to the VTM with my domestic helper to update her mobile phone number for future OTPs as well as her email address. This could have been avoided and really unnecessary had your officer just guided me through the process.",
#             "Ur high tech video teller machine at BT timah plaza branch apparently dun work at all. Dun even allowed me to access say error. I trying to replace my passbook. Inserted n key in password. No access error ask me go counter."
#         ]
#     },
#     {
#         "subproduct": "Phone Banking",
#         "actionable_category": "To Fix",
#         "action": "Review and update the phone banking system to ensure accurate account information retrieval and transaction history access, while restoring the previous menu structure for account balance inquiries.",
#         "feedback_count": 3,
#         "feedback_data": [
#             "cm mentioned used to press 2 and can check account last 5 transaction but now when call in, he press 2 as per usual way, it direct him to the cso instead. Cm mentioned something wrong with the system or there is a change. If there is a change, cm hope it caan be revert to the old ways instead",
#             "CM does not like the selections and options",
#             "cm is frustrated all the time she calls in for  phone banking details given were not correct checking on account transaction  she wish to highligh to IT  issues :  information not avail unable to retrieve transaction  history"
#         ]
#     },
#     {
#         "subproduct": "Paylah!",
#         "actionable_category": "To Fix",
#         "action": "Improve clarity and consistency in transaction information and payment flow to enhance user experience.",
#         "feedback_count": 3,
#         "feedback_data": [
#             "Cm suggest for bank to ensure that merchant indicate their company name/more description for the transfer made via scanning the merchant's QR code. Cm was not aware that the above transaction was for a money changer as the name does not ring any bell until he find out further.",
#             "cm feedback that the usability of platform for the wallet is confusing as cm was able to purchase qrangbao n direct debit from acc when wallet bal was 0.00 at 22 Mar 2024 15:11:44  & af cm change the enable auto debit credit wallet function, cm was unable to do so & cm needed to top up to wallet in order to purchase. If enable auto debit/ cr from acc to wallet, cm shouldnt be prompted error stating wallet has insufficient funds",
#             "cm suggest start paylah hawker promo at later timing."
#         ]
#     },
#     {
#         "subproduct": "Others",
#         "actionable_category": "To Promote",
#         "action": "Continue to cultivate a culture of excellent customer service by recognizing and rewarding employees who consistently provide positive experiences.",
#         "feedback_count": 1,
#         "feedback_data": [
#             "Rated excellent customer service experience. I had several matters to deal with at DBS Treasures today. I experienced excellent service throughout. Officer were pleasant and very professional. "
#         ]
#     },
#     {
#         "subproduct": "Treasures - Others",
#         "actionable_category": "To Fix",
#         "action": "Improve responsiveness and communication from Relationship Managers (RMs) by implementing training programs on proactive communication, timely response, and appropriate communication channels.",
#         "feedback_count": 3,
#         "feedback_data": [
#             "I am a loyal customer of DBS Treasures and have been banking for a long time. I became a DBS treasures client a few years back. Since then, I have had multiple RM servicing my account. With the most recent one being Zhi Qiang. I have actually given feedback to DBS about his lack of proactiveness and slow in responding. He does not provide information and options readily. Many times, I have to find out about the possibilities and then ask him about it. I am not sure if it's because I am not high net worth enough or is he just not as competent.    The latest being a request from me this morning - asking him how I can sell a US share that has been delisted from Nasdaq. We were having a message exchange on whats app and then he went quiet. I reached out again about 30mins ago and there is an auto message saying that he's on block leave. He could have mentioned that he is on block leave while we were chatting this morning.    Can I please request again to change the RM. It may be difficult to move my funds from DBS but it's always possible, it just takes time. I just need a good and responsive RM.  #2nd Email: Thank you for responding. Appreciate it. Brian has helped me with the request on selling a delisted US stock. However, I am still waiting for him/the team to come back on the request which I have asked Zhiqiang previously. I have also mentioned that to Sophia.   I would also like to share my comments on the 'service' from your Treasures team. I am not sure if the team is relatively young or they are just overworked and unhappy. While Brian did solve my issue on the US stock, the way he liaised with me on whats app was rather 'not ideal'. I would like to think that he did not do that intentionally. But maybe it's the way that he responds. (Actually Zhi qiang responds similarly too). Maybe they need to be trained how they should respond on whats app. Because it's just words without audio, the choice of words and structuring of the sentences should be used with more tact I reckon.  ",
#             "Lately, we are increasingly concerned about the support received by DBS Treasures. Particularly the \u201crevolving door\u201d experience of ever changing RM\u2019s, four of them, no less, in less than a year:   ",
#             "I am taking you up on your offer below and writing to you to bring to your attention really disappointing service levels from your team over the past few months. Attached is a recent example of one of your colleagues calling me three times in the middle of a work day about setting up a meeting around investment options against my SRS funds and not getting back to me. I wrote to my RM and he hasn't replied either (this happens often). There have been several such instances over the past couple of years.  Over the last year or so, I have moved my investments out to a private firm called GYC, my credit card relationship out to Citi, Health and Life Insurance out to private agents and brokerage relationship out to Tiger Brokers - I'm sure my RM is able to see this activity in your systems but has not really done much about any of it. I am now very close to moving my primary banking relationship out to another bank as well.  Will be really good to see the DBS relationship team up its game a bit and be more responsive to clients, meet their needs better."
#         ]
#     },
#     {
#         "subproduct": "Remittance",
#         "actionable_category": "To Fix",
#         "action": "Improve security measures and communication protocols for international remittances, including addressing concerns about address disclosure and implementing robust fraud prevention mechanisms.",
#         "feedback_count": 4,
#         "feedback_data": [
#             "did a money exchange sgd and renmimbi  accompanied by male friend , visit the bank . Claimed that she has sent money to the recipient ., of which the first time they has their deal done . The second transaction after they transfer the money , the other party did not respond  Arrogantly, the male friend insist that the bank freeze the other bank account.  Advised him to report to the police . Apparently, the case is already handle by the IO - police",
#             "Cm is transferring to his own account and does not see the need for risk review and does not appreciate the delay. Cm wants to relay his feedback to management as this caused delay to fund his trade",
#             "CM has a concern that her mailing address is shown to bank in thailand when she does an OTT.  She would like to feedback that this is very risky and the bank should musk our mailing or residential address,",
#             "cm wish to feedback to increase the daily limit for promptpay for emergency cases and if needed to do ewss checks"
#         ]
#     },
#     {
#         "subproduct": "Payments",
#         "actionable_category": "To Amplify",
#         "action": "Improve the feedback form by reducing the character limit to encourage more detailed and specific feedback from customers.",
#         "feedback_count": 1,
#         "feedback_data": [
#             "reduce 10% of characters from feedback form and give to  Paynow in that way we can have at 50 or more character"
#         ]
#     },
#     {
#         "subproduct": "Smart Buddy",
#         "actionable_category": "To Amplify",
#         "action": "Clarify eligibility criteria for promotions and ensure clear communication regarding program participation.",
#         "feedback_count": 1,
#         "feedback_data": [
#             "cm wants to feedback for existing users of the smart buddy to be eligible to apply for the disney strap cm read online that its for new applicant only"
#         ]
#     },
#     {
#         "subproduct": "CCTR",
#         "actionable_category": "To Fix",
#         "action": "Improve accuracy and consistency of information displayed on mobile bill statements.",
#         "feedback_count": 1,
#         "feedback_data": [
#             "bill statement on phone gave cm wrong info"
#         ]
#     },
#     {
#         "subproduct": "PayNow",
#         "actionable_category": "To Fix",
#         "action": "Investigate and resolve issues preventing PayNow functionality via MB (Mobile Banking).",
#         "feedback_count": 1,
#         "feedback_data": [
#             "CM said she was not able to use PayNow via MB"
#         ]
#     }
# ]
